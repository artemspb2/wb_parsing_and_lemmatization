# %%
import requests
import json
import pandas as pd
from tqdm import tqdm

# %%
url = 'https://www.wildberries.ru/webapi/menu/main-menu-ru-ru.json'
headers = {'Accept': "*/*", 'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
response = requests.get(url, headers=headers)
data = response.json()
with open('wb_catalogs_data.json', 'w', encoding='UTF-8') as file:
    json.dump(data, file, indent=2, ensure_ascii=False)
    print(f'Данные сохранены в wb_catalogs_data.json')
# Out:
# Данные сохранены в wb_catalogs_data.json

# %%
def get_catalogs_wb(target):
    """получение каталога вб"""
    url = 'https://www.wildberries.ru/webapi/menu/main-menu-ru-ru.json'
    headers = {'Accept': "*/*", 'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
    response = requests.get(url, headers=headers).json()

    with open('wb_catalogs_data.json', 'w', encoding='UTF-8') as file:
        json.dump(response, file, indent=2, ensure_ascii=False)
        print(f'Данные сохранены в wb_catalogs_data_sample.json')
    data_list = []
    for d in response:
        try:
            for child in d['childs']:
                if target == child['url']:
                    data_list.append({
                        'category_name': child['name'],
                        'category_url': child['url'],
                        'shard': child['shard'],
                        'query': child['query']})
                else:
                    for sub_child in child['childs']:
                        data_list.append({
                            'category_name': sub_child['name'],
                            'category_url': sub_child['url'],
                            'shard': sub_child['shard'],
                            'query': sub_child['query']})
        except:
            # print(f'не имеет дочерних каталогов *{d["name"]}*')
            continue

    return data_list


def search_category_in_catalog(target, catalog_list):
    """пишем проверку пользовательской ссылки на наличии в каталоге"""
    try:
        for catalog in catalog_list:
            if catalog['category_url'] == target:
                print(f'найдено совпадение: {catalog["category_name"]}')
                name_category = catalog['category_name']
                shard = catalog['shard']
                query = catalog['query']
                return name_category, shard, query
            else:
                # print('нет совпадения')
                pass
    except:
        print('Данный раздел не найден!')


def get_data_from_json(json_file):
    """извлекаем из json интересующие нас данные"""
    data_list = []
    for data in json_file['data']['products']:
        try:
            price = int(data["priceU"] / 100)
        except:
            price = 0
        data_list.append({
            'Наименование': data['name'],
            'id': data['id'],
            'Скидка': data['sale'],
            'Цена': price,
            'Цена со скидкой': int(data["salePriceU"] / 100),
            'Бренд': data['brand'],
            'id бренда': int(data['brandId']),
            'feedbacks': data['feedbacks'],
            'rating': data['rating'],
            'Ссылка': f'https://www.wildberries.ru/catalog/{data["id"]}/detail.aspx?targetUrl=BP'
        })
    return data_list


def get_content(shard, query, low_price=None, top_price=None):
    # вставляем ценовые рамки для уменьшения выдачи, вилбериес отдает только 100 страниц
    headers = {'Accept': "*/*", 'User-Agent': "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
    data_list = []
    for page in tqdm(range(1, 101)):

        # url = f'https://wbxcatalog-ru.wildberries.ru/{shard}' \
        #       f'/catalog?appType=1&curr=rub&dest=-1029256,-102269,-1278703,-1255563' \
        #       f'&{query}&lang=ru&locale=ru&sort=sale&page={page}' \
        #       f'&priceU={low_price * 100};{top_price * 100}'
        url = f'https://catalog.wb.ru/catalog/{shard}/catalog?appType=1&curr=rub&dest=-1075831,-77677,-398551,12358499' \
              f'&locale=ru&page={page}&priceU={low_price * 100};{top_price * 100}' \
              f'&reg=0&regions=64,83,4,38,80,33,70,82,86,30,69,1,48,22,66,31,40&sort=popular&spp=0&{query}'
        data = requests.get(url, headers=headers).json()
        if len(get_data_from_json(data)) > 0:
            data_list.extend(get_data_from_json(data))
        else:
            print(f'Сбор данных завершен.')
            break
    return data_list


def save_excel(data, filename): 
    """сохранение результата в excel файл"""
    df = pd.DataFrame(data)
    writer = pd.ExcelWriter(f'{filename}.xlsx')
    df.to_excel(writer, 'data')
    writer.save()
    print(f'Все сохранено в {filename}.xlsx')


def parser(url, low_price, top_price):
    # получаем список каталогов
    target = url.split('https://www.wildberries.ru')[-1]
    catalog_list = get_catalogs_wb(target)
    try:
        # поиск введенной категории в общем каталоге
        name_category, shard, query = search_category_in_catalog(target, catalog_list=catalog_list)
        # сбор данных в найденном каталоге
        data_list = get_content(shard=shard, query=query, low_price=low_price, top_price=top_price)
        # сохранение найденных данных
        save_excel(data_list, f'{name_category}_from_{low_price}_to_{top_price}')
    except TypeError:
        print('Ошибка! Возможно не верно указан раздел. Удалите все доп фильтры с ссылки')
    except PermissionError:
        print('Ошибка! Вы забыли закрыть созданный ранее excel файл. Закройте и повторите попытку')


if __name__ == '__main__':
    """ссылку на каталог или подкаталог, указывать без фильтров (без ценовых, сортировки и тд.)"""
    # url = input('Введите ссылку на категорию для сбора: ')
    # low_price = int(input('Введите минимальную сумму товара: '))
    # top_price = int(input('Введите максимульную сумму товара: '))

    """данные для теста. собираем товар с раздела велосипеды в ценовой категории от 0 до 300 рубдей"""
    url = 'https://www.wildberries.ru/catalog/sport/vidy-sporta/komandnye-vidy-sporta'
    
 
    low_price = 0
    top_price = 300

    parser(url, low_price, top_price)
# Out:
# Данные сохранены в wb_catalogs_data_sample.json
# найдено совпадение: Командные виды спорта
#  59%|███████████████████████████████████████████████▊                                 | 59/100 [00:29<00:20,  2.03it/s]
# Сбор данных завершен.
# Все сохранено в Командные виды спорта_from_0_to_300.xlsx

# %%
df = pd.read_excel('Командные виды спорта_from_0_to_300.xlsx')
# Вайлдберрис ограничивает выдачу 100 страницами, на каждой по 100 карточек, возможный максимум для парсинга - 
# 10 000 карточек, поэтому ограничиваем поиск по ценовой категории, пусть будут самые дешевые товары - 
# до 300 рублей

# %%
df
# Out:
#       Unnamed: 0                                       Наименование  \
# 0              0  Носки мужские набор белые черные короткие пода...
# 1              1  Носки мужские набор высокие белые черные длинн...
# 2              2  Носки мужские набор короткие спортивные серые ...
# 3              3                 Фитнес-резинки эспандер набор 5 шт
# 4              4  Носки мужские набор высокие белые черные длинн...
# ...          ...                                                ...
# 5890        5890                        Игла для мяча иголка насоса
# 5891        5891    Игла для мяча, футбольного, баскетбольного 10шт
# 5892        5892  Носки женские низкие с принтом короткие мужски...
# 5893        5893  Носки женские низкие с принтом короткие мужски...
# 5894        5894                        желтая футболка для малышей
#
#              id  Скидка  Цена  Цена со скидкой                     Бренд  \
# 0      12246409      60   879              351                  ECOBRAND
# 1      12246403      59   919              376                  ECOBRAND
# 2      12246407      63   919              340                  ECOBRAND
# 3      19197061      75   920              230  Резинки для фитнеса PWR!
# 4      12246401      62   919              349                  ECOBRAND
# ...         ...     ...   ...              ...                       ...
# 5890  160971873      65   500              175               игла иголки
# 5891  161223350       0   199              199                       А-Я
# 5892   28620379      38   500              310                     MOGZY
# 5893   28620732      34   500              330                     MOGZY
# 5894  101293564      78  1100              242                 Филинёнок
#
#       id бренда  feedbacks  rating  \
# 0         71300      16648       5
# 1         71300      20397       5
# 2         71300      16648       5
# 3        938049      19902       5
# 4         71300      20397       5
# ...         ...        ...     ...
# 5890  310752948          0       0
# 5891     530250          0       0
# 5892      94646        194       5
# 5893      94646        223       5
# 5894    2585947          0       0
#
#                                                  Ссылка
# 0     https://www.wildberries.ru/catalog/12246409/de...
# 1     https://www.wildberries.ru/catalog/12246403/de...
# 2     https://www.wildberries.ru/catalog/12246407/de...
# 3     https://www.wildberries.ru/catalog/19197061/de...
# 4     https://www.wildberries.ru/catalog/12246401/de...
# ...                                                 ...
# 5890  https://www.wildberries.ru/catalog/160971873/d...
# 5891  https://www.wildberries.ru/catalog/161223350/d...
# 5892  https://www.wildberries.ru/catalog/28620379/de...
# 5893  https://www.wildberries.ru/catalog/28620732/de...
# 5894  https://www.wildberries.ru/catalog/101293564/d...
#
# [5895 rows x 11 columns]

# %%
df['Наименование'].value_counts()
# До 300 рублей в разделе спортивных товаров для командных видов спорта можно в основном найти носки и нижнее белье
# Наименование разное, суть отдна
# Out:
# Носки                                                          245
# Носки женские высокие с принтом длинные мужские спортивные      71
# Гетры                                                           59
# Гетры Спортивные                                                58
# Носки женские высокие с принтом теплые плотные шерстяные        54
#                                                               ...
# Шорты для мальчика для девочки спортивные                        1
# Гольфы женские теплые белые высокие вязаные плотные высокие      1
# Шайба хоккейная, хоккей, взрослая                                1
# Носки женские короткие набор спорт повседневные в подарок        1
# желтая футболка для малышей                                      1
# Name: Наименование, Length: 2065, dtype: int64

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in c:\users\artem\anaconda3\lib\site-packages (3.7)
# Requirement already satisfied: click in c:\users\artem\anaconda3\lib\site-packages (from nltk) (8.0.4)
# Requirement already satisfied: tqdm in c:\users\artem\anaconda3\lib\site-packages (from nltk) (4.64.1)
# Requirement already satisfied: joblib in c:\users\artem\anaconda3\lib\site-packages (from nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\artem\anaconda3\lib\site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: colorama in c:\users\artem\anaconda3\lib\site-packages (from click->nltk) (0.4.5)

# %%
# !pip install collections
# Out:
# ERROR: Could not find a version that satisfies the requirement collections (from versions: none)
# ERROR: No matching distribution found for collections

# %%
# Надо попробовать лемматизировать наименование
#
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4') # сработало?
from nltk.stem import WordNetLemmatizer
from collections import Counter

# %%
# Инициализируем лемматизатор
lemmatizer = WordNetLemmatizer()

# %%
# Создаем функцию для лемматизации текста
def lemmatize_text(text):
    words = text.lower().split()
    lemmas = [lemmatizer.lemmatize(word) for word in words]
    return lemmas

# %%
# Применяем функцию lemmatize_text ко всем значениям столбца 'Наименование'
lemmatized_words = df['Наименование'].apply(lemmatize_text).sum()

# %%
# Посчитаем наиболее часто встречающиеся леммы с помощью Counter
most_common_lemmas = Counter(lemmatized_words).most_common()

# %%
# Посчитаем наиболее часто встречающиеся леммы с помощью Counter
most_common_lemmas
# Out:
# [('носки', 2098),
#  ('для', 1735),
#  ('с', 1113),
#  ('высокие', 1056),
#  ('спортивные', 878),
#  ('гетры', 804),
#  ('мужские', 720),
#  ('принтом', 703),
#  ('женские', 683),
#  ('набор', 601),
#  ('длинные', 597),
#  ('гольфы', 509),
#  ('футбольные', 453),
#  ('и', 403),
#  ('на', 333),
#  ('пары', 312),
#  ('1', 307),
#  ('белые', 306),
#  ('спортивный', 293),
#  ('хлопок', 290),
#  ('кинезио', 277),
#  ('короткие', 269),
#  ('тела', 268),
#  ('лица', 262),
#  ('тейп', 257),
#  ('в', 255),
#  ('флаг', 247),
#  ('пара', 242),
#  ('детские', 240),
#  ('2', 230),
#  ('мяч', 212),
#  ('3', 201),
#  ('наколенники', 194),
#  ('спортивная', 194),
#  ('5', 191),
#  ('шт', 190),
#  ('милые', 187),
#  ('свисток', 183),
#  ('прикольные', 180),
#  ('черные', 163),
#  ('рисунком', 163),
#  ('пар', 160),
#  ('парные', 157),
#  ('детская', 154),
#  ('шайба', 154),
#  ('тейпы', 148),
#  ('подарок', 147),
#  ('бандаж', 145),
#  ('рубчик', 142),
#  ('мальчика', 137),
#  ('см', 135),
#  ('россии', 135),
#  ('теплые', 127),
#  ('+', 126),
#  ('чехлы', 122),
#  ('коньков', 116),
#  ('танцев', 115),
#  ('бутылка', 111),
#  ('майка', 104),
#  ('цветные', 104),
#  ('плотные', 101),
#  ('насос', 95),
#  ('надписями', 95),
#  ('шерстяные', 95),
#  ('яркие', 94),
#  ('однотонные', 94),
#  ('мяча', 90),
#  ('лента', 88),
#  ('спорта', 87),
#  ('наколенник', 86),
#  ('волейбольный', 85),
#  ('хоккейная', 84),
#  ('воды', 83),
#  ('судейский', 81),
#  ('волейбола', 78),
#  ('клюшка', 74),
#  ('мягкие', 73),
#  ('9', 70),
#  ('х', 69),
#  ('суставов', 69),
#  ('футбола', 69),
#  ('девочек', 68),
#  ('кальсоны', 68),
#  ('голеностопный', 64),
#  ('фитнеса', 62),
#  ('хб', 62),
#  ('игла', 62),
#  ('спортивные,', 62),
#  ('скакалка', 61),
#  ('фишки', 57),
#  ('от', 56),
#  ('эластичный', 55),
#  ('хлопковые', 54),
#  ('комплект', 54),
#  ('мл', 53),
#  ('универсальные', 52),
#  ('конусы', 52),
#  ('см,', 51),
#  ('10', 50),
#  ('тела,', 49),
#  ('ортез', 49),
#  ('низкие', 49),
#  ('из', 48),
#  ('мячей', 47),
#  ('колена', 46),
#  ('-', 46),
#  ('морщин', 45),
#  ('мая', 45),
#  ('гимнастики', 43),
#  ('капа', 41),
#  ('детей', 41),
#  ('пара,', 41),
#  ('без', 41),
#  ('противоскользящие', 40),
#  ('подростковые', 40),
#  ('летняя', 40),
#  ('бинт', 39),
#  ('физкультуры', 39),
#  ('полосками', 39),
#  ('унисекс', 39),
#  ('гербом', 38),
#  ('суппорт', 37),
#  ('большой', 37),
#  ('ручной', 37),
#  ('эспандер', 36),
#  ('unlim', 36),
#  ('сустав', 36),
#  ('пластиковая', 35),
#  ('девочки', 34),
#  ('тренировок', 34),
#  ('боксерская', 33),
#  ('напульсники', 33),
#  ('зимние', 33),
#  ('школу', 32),
#  ('модные', 32),
#  ('тейп,', 32),
#  ('надписью', 32),
#  ('взрослая', 31),
#  ('глаз', 30),
#  ('спорт', 30),
#  ('принт', 30),
#  ('компрессионные', 30),
#  ('полоску', 30),
#  ('хоккейные', 30),
#  ('женские,', 30),
#  ('ортопедический', 29),
#  ('кинезиотейп', 29),
#  ('похудения', 28),
#  ('победы', 28),
#  ('груди', 28),
#  ('веселые', 28),
#  ('лезвия', 28),
#  ('бандажный', 28),
#  ('танцев,', 27),
#  ('соревнования', 27),
#  ('махровые', 27),
#  ('защита', 26),
#  ('насоса', 26),
#  ('90', 26),
#  ('штук', 26),
#  ('футболка', 26),
#  ('4', 26),
#  ('носков', 26),
#  ('триколор', 25),
#  ('ног', 25),
#  ('лонги', 25),
#  ('коленный', 25),
#  ('м', 25),
#  ('смешные', 25),
#  ('знамя', 24),
#  ('суставов,', 24),
#  ('девочки,', 24),
#  ('полосатые', 24),
#  ('голеностоп', 24),
#  ('влагостойкая', 24),
#  ('футбольные,', 24),
#  ('60', 23),
#  ('термобелье', 23),
#  ('иглой', 23),
#  ('резинке', 23),
#  ('летние', 22),
#  ('фиксатор', 22),
#  ('взрослых', 22),
#  ('большой,', 22),
#  ('6', 22),
#  ('настольный', 22),
#  ('короткие,', 22),
#  ('мальчику', 22),
#  ('девочке', 22),
#  ('малышу', 22),
#  ('400', 22),
#  ('напульсник', 22),
#  ('8', 22),
#  ('флажки', 22),
#  ('и10', 22),
#  ('лица,', 21),
#  ('металлический', 21),
#  ('vonherz', 21),
#  ('шнурке', 21),
#  ('пластиковый', 21),
#  ('тренировочный', 21),
#  ('шорты', 20),
#  ('повязка', 20),
#  ('капитанская', 20),
#  ('ссср', 20),
#  ('corporation', 20),
#  ('махровым', 20),
#  ('следом', 20),
#  ('накачивания', 20),
#  ('малый', 20),
#  ('флагштоком', 20),
#  ('детский', 20),
#  ('принтами,', 20),
#  ('марта', 20),
#  ('прикольной', 20),
#  ('golf', 19),
#  ('взрослые', 19),
#  ('сетка', 19),
#  ('маленький', 19),
#  ('тактический', 19),
#  ('самофиксирующийся', 19),
#  ('мячик', 18),
#  ('подарочные', 18),
#  ('ортопедические', 18),
#  ('мальчика,', 18),
#  ('надувной', 18),
#  ('когезивный', 18),
#  ('тату', 18),
#  ('вымпел', 18),
#  ('по', 17),
#  ('начесом', 17),
#  ('хлопка', 17),
#  ('аниме', 17),
#  ('флаги', 17),
#  ('волейбол', 17),
#  ('серые', 16),
#  ('чехол', 16),
#  ('мужских', 16),
#  ('разноцветные', 16),
#  ('дриблинга', 16),
#  ('мм', 16),
#  ('новогодние', 16),
#  ('500', 16),
#  ('лезвий', 16),
#  ('мл).', 16),
#  ('21', 16),
#  ('кистевой', 16),
#  ('боксе', 16),
#  ('волейболу', 16),
#  ('высота', 16),
#  ('резинки', 15),
#  ('оверсайз', 15),
#  ('защиты', 15),
#  ('кинезиотейпы', 15),
#  ('футбольный', 15),
#  ('мяча,', 15),
#  ('14', 15),
#  ('руку', 15),
#  ('нарядные', 15),
#  ('носок', 15),
#  ('флагов', 15),
#  ('размер', 14),
#  ('10,5,3', 14),
#  ('высокие,', 14),
#  ('баскетбольный', 14),
#  ('подставке,', 14),
#  ('следки', 14),
#  ('12', 14),
#  ('укороченные', 14),
#  ('гимнастическая', 13),
#  ('белье', 13),
#  ('спорта,', 13),
#  ('нескользящие', 13),
#  ('физкультуру', 13),
#  ('23', 13),
#  ('вышивкой', 13),
#  ('подростков', 13),
#  ('(спортивная,', 13),
#  ('300', 13),
#  ('конус', 13),
#  ('активного', 13),
#  ('отдыха', 13),
#  ('игл', 13),
#  ('фитнес-резинки', 12),
#  ('одночелюстная', 12),
#  ('женщин', 12),
#  ('фитбола', 12),
#  ('под', 12),
#  ('подштанники', 12),
#  ('gt—sport', 12),
#  ('иглы', 12),
#  ('пластырь', 12),
#  ('школьные', 12),
#  ('повседневные', 12),
#  ('рюкзак', 12),
#  ('my', 12),
#  ('bottle,', 12),
#  ('средний', 12),
#  ('d-12', 12),
#  ('игры', 11),
#  ('голеностопа', 11),
#  ('коробке', 11),
#  ('скоростная', 11),
#  ('прыгалки', 11),
#  ('настольный,', 11),
#  ('коротких', 11),
#  ('компрессионный', 11),
#  ('лентой', 11),
#  ('тактические', 11),
#  ('фигурные', 11),
#  ('2,5', 11),
#  ('эспандеры', 11),
#  ('деревянный', 11),
#  ('флажок', 11),
#  ('волейбольные', 11),
#  ('кг', 11),
#  ('дошкольный', 11),
#  ('садик', 11),
#  ('шарика', 11),
#  ('воды,', 11),
#  ('мо…', 11),
#  ('значок', 11),
#  ('синие', 10),
#  ('россии,', 10),
#  ('живота', 10),
#  ('c', 10),
#  ('хоккей', 10),
#  ('выше', 10),
#  ('россии",', 10),
#  ('шеи', 10),
#  ('зубов', 10),
#  ('термо', 10),
#  ('колено', 10),
#  ('до', 10),
#  ('рф', 10),
#  ('пластиковые', 10),
#  ('чехле', 10),
#  ('кинезиологический', 10),
#  ('большая', 10),
#  ('брелок-свисток', 10),
#  ('d-19', 10),
#  ('георгиевской', 10),
#  ('отеков', 9),
#  ('aspiration,', 9),
#  ('тонкие', 9),
#  ('1пара', 9),
#  ('сустава', 9),
#  ('спортивных', 9),
#  ('подарочный', 9),
#  ('45', 9),
#  ('ссср",', 9),
#  ('защитные', 9),
#  ('белый', 9),
#  ('коньки', 9),
#  ('универсальный', 9),
#  ('мальчиков', 9),
#  ('подставке', 9),
#  ('вязаные', 9),
#  ('малышей', 9),
#  ('5шт', 9),
#  ('носка', 9),
#  ('разметочный', 9),
#  ('колен', 9),
#  ('резиновый,', 9),
#  ('разметки', 9),
#  ('самоклеющийся', 9),
#  ('4,5', 9),
#  ('универсальный,', 9),
#  ('волейбола,', 8),
#  ('8см', 8),
#  ('гербом,', 8),
#  ('хлопк', 8),
#  ('февраля', 8),
#  ('30', 8),
#  ('шайбы', 8),
#  ('фитнес', 8),
#  ('носа', 8),
#  ('туристический', 8),
#  ('длина', 8),
#  ('комплекте', 8),
#  ('свистки', 8),
#  ('мая,день', 8),
#  ('флажков', 8),
#  ('со', 8),
#  ('носочки', 8),
#  ('номером', 8),
#  ('мл,', 8),
#  ('ботфорты,', 8),
#  ('японски…', 8),
#  ('тренера', 8),
#  ('15х22', 8),
#  ('1,5м', 7),
#  ('бега', 7),
#  ('молодежные', 7),
#  ('классические', 7),
#  ('металл', 7),
#  ('запаха', 7),
#  ('синий', 7),
#  ('зодиака', 7),
#  ('антифог', 7),
#  ('желтые', 7),
#  ('тейпы,', 7),
#  ('герба', 7),
#  ('запястье', 7),
#  ('громкий', 7),
#  ('хоккейный', 7),
#  ('пластиковом', 7),
#  ('поддержания', 7),
#  ('спортивный,', 7),
#  ('капроновые', 7),
#  ('диаметр', 7),
#  ('1шт', 7),
#  ('алюминиевый', 7),
#  ('аксессуары', 7),
#  ('60*90', 7),
#  ('футбольного,', 7),
#  ('баскетбольного', 7),
#  ('tape', 6),
#  ('налокотник', 6),
#  ('повседневная', 6),
#  ('100%', 6),
#  ('подтяжки', 6),
#  ('скоростная.', 6),
#  ('иголка', 6),
#  ('бравл', 6),
#  ('старс', 6),
#  ('команд', 6),
#  ('"пограничные', 6),
#  ('войска",', 6),
#  ('obsorption', 6),
#  ('коленного', 6),
#  ('войска', 6),
#  ('арбитра', 6),
#  ('прыгалка', 6),
#  ('650', 6),
#  ('белые,', 6),
#  ('бутылочка', 6),
#  ('чулки', 6),
#  ('гольфы,', 6),
#  ('гетры,', 6),
#  ('коньков,', 6),
#  ('35см', 6),
#  ('утепленные', 6),
#  ('штоком', 6),
#  ('машины', 6),
#  ('двойного', 6),
#  ('действия', 6),
#  ('полоской', 6),
#  ('подарочной', 6),
#  ('щенячий', 6),
#  ('патруль', 6),
#  ('регулировкой', 6),
#  ('стакан', 6),
#  ('складной', 6),
#  ('малая', 6),
#  ('5см*5м,', 6),
#  ('"с', 6),
#  ('днём', 6),
#  ('мма', 6),
#  ('кигбоксинг', 6),
#  ('флорбольный', 6),
#  ('pro-line', 6),
#  ('72', 6),
#  ('компактный', 5),
#  ('локтя', 5),
#  ('жгут', 5),
#  ('наколенник,', 5),
#  ('бельевая', 5),
#  ('спортики', 5),
#  ('баскетбола', 5),
#  ('шайба,', 5),
#  ('тренировки', 5),
#  ('однотоники', 5),
#  ('шариков', 5),
#  ('трубчатые', 5),
#  ('российской', 5),
#  ('серп', 5),
#  ('игровая', 5),
#  ('глобус', 5),
#  ('пляж', 5),
#  ('учеба', 5),
#  ('февраля,', 5),
#  ('фишек', 5),
#  ('батута', 5),
#  ('напитков', 5),
#  ('налокотники', 5),
#  ('свистков', 5),
#  ('коньки,', 5),
#  ('подставка', 5),
#  ('л', 5),
#  ('бесшовные', 5),
#  ('жаккардовые', 5),
#  ('эмоджи', 5),
#  ('двумя', 5),
#  ('зеленые', 5),
#  ('полоску,', 5),
#  ('г', 5),
#  ('sv', 5),
#  ('липучке', 5),
#  ('принта', 5),
#  ('коньки.', 5),
#  ('коньков.чехол', 5),
#  ('носки,', 5),
#  ('пятки', 5),
#  ('ниже', 5),
#  ('14-16', 5),
#  ('складная', 5),
#  ('матраса', 5),
#  ('велосипедный', 5),
#  ('тритана', 5),
#  ('кинезио,', 5),
#  ('40', 5),
#  ('840', 5),
#  ('пластика', 5),
#  ('георгиевская', 5),
#  ('баскетбольный,', 5),
#  ('(в', 5),
#  ('штуки', 5),
#  ('5х500см', 5),
#  ('победы!"', 5),
#  ('1941-1945', 5),
#  ('занчок', 5),
#  ('9мая', 5),
#  ('"дельфин"', 5),
#  ('путешествие,', 5),
#  ('8х12', 5),
#  ('металлополимерная,', 5),
#  ('ароматизированные', 5),
#  ('свисток-брелок', 5),
#  ('б', 4),
#  ('90*145см', 4),
#  ('сад', 4),
#  ('brawl', 4),
#  ('star', 4),
#  ('хлопковая', 4),
#  ('походов', 4),
#  ('удлиненн', 4),
#  ('рисунок', 4),
#  ('нейтрализатор', 4),
#  ('шаров', 4),
#  ('круга', 4),
#  ('роликов', 4),
#  ('динозаврами', 4),
#  ('80%', 4),
#  ('авто', 4),
#  ('карточки', 4),
#  ('2.2м.', 4),
#  ('трико', 4),
#  ('малышей,', 4),
#  ('кинезио,пластырь', 4),
#  ('выпускной', 4),
#  ('стиле', 4),
#  ('шариком,', 4),
#  ('металлический,', 4),
#  ('брелок', 4),
#  ('холодных', 4),
#  ('детское', 4),
#  ('450', 4),
#  ('гороскоп', 4),
#  ('7', 4),
#  ('тренировоке', 4),
#  ('резинка', 4),
#  ('спрей', 4),
#  ('очков', 4),
#  ('знаки', 4),
#  ('обуви', 4),
#  ('победы,знамя', 4),
#  ('2шт', 4),
#  ('против', 4),
#  ('чёрные', 4),
#  ('голубые', 4),
#  ('зимнее', 4),
#  ('регулируемая', 4),
#  ('фишка', 4),
#  ('ленточный', 4),
#  ('один', 4),
#  ('хоккейная,', 4),
#  ('60х90', 4),
#  ('дрессировки', 4),
#  ('св…', 4),
#  ('игровым', 4),
#  ('домашние', 4),
#  ('термоноски', 4),
#  ('желтый', 4),
#  ('розовый', 4),
#  ('пуховые', 4),
#  ('корея', 4),
#  ('5х5', 4),
#  ('90х145', 4),
#  ('красные', 4),
#  ('16-18см', 4),
#  ('микки', 4),
#  ('20см', 4),
#  ('тейпирование', 4),
#  ('тренировочная', 4),
#  ('3шт', 4),
#  ('петлей', 4),
#  ('цвета', 4),
#  ('19', 4),
#  ('камера', 4),
#  ('футбольного', 4),
#  ('h-15', 4),
#  ('30х40', 4),
#  ('значек', 4),
#  ('fox40', 4),
#  ('sharx', 4),
#  ('победа!', 4),
#  ('гр', 4),
#  ('махровый', 4),
#  ('"classic"', 4),
#  ('дивари', 4),
#  ('бутылка"', 4),
#  ('чехле)', 4),
#  ('карабином', 4),
#  ('волейбольного,', 4),
#  ('поясницы', 4),
#  ('силиконовая', 3),
#  ('наборе', 3),
#  ('простая', 3),
#  ('🧦носки', 3),
#  ('резиновые', 3),
#  ('5метров', 3),
#  ('пабло', 3),
#  ('"россия"', 3),
#  ('дышащая', 3),
#  ('гимнастики,', 3),
#  ('оранжевые', 3),
#  ('подставкой', 3),
#  ('лонг', 3),
#  ('шерсти', 3),
#  ('день', 3),
#  ('победы,', 3),
#  ('коробка', 3),
#  ('сушки', 3),
#  ('двухслойная', 3),
#  ('лифтинг', 3),
#  ('о…', 3),
#  ('машину', 3),
#  ('cotton,', 3),
#  ('занятий', 3),
#  ('средней', 3),
#  ('длины', 3),
#  ('судейские', 3),
#  ('гольфины', 3),
#  ('"вдв', 3),
#  ('новогодние,', 3),
#  ('знак', 3),
#  ('кот', 3),
#  ('парашюте', 3),
#  ('держатель', 3),
#  ('однотонных', 3),
#  ('папе', 3),
#  ('мужу', 3),
#  ('баскетбольная', 3),
#  ('гипоаллергенный', 3),
#  ('г…', 3),
#  ('фигурных', 3),
#  ('чемпион', 3),
#  ('весы', 3),
#  ('(спортивная', 3),
#  ('530', 3),
#  ('"морская', 3),
#  ('крышкой', 3),
#  ('очищающий', 3),
#  ('запотевания', 3),
#  ('металлические', 3),
#  ('резиновая', 3),
#  ('медведь', 3),
#  ('145', 3),
#  ('мужские,', 3),
#  ('перфорированный', 3),
#  ('молот', 3),
#  ('тейпов', 3),
#  ('спорте', 3),
#  ('шариком', 3),
#  ('бежевые', 3),
#  ('кинезиотейпов', 3),
#  ('женская', 3),
#  ('коричневые', 3),
#  ('средство', 3),
#  ('стену', 3),
#  ('шт.', 3),
#  ('дачи', 3),
#  ('бокса', 3),
#  ('протектор', 3),
#  ('"', 3),
#  ('насадкой', 3),
#  ('рисунком,', 3),
#  ('переноска', 3),
#  ('папина', 3),
#  ('дочка', 3),
#  ('косплей', 3),
#  ('пластик', 3),
#  ('карманом', 3),
#  ('бега…', 3),
#  ('москва', 3),
#  ('стандартная', 3),
#  ('игра', 3),
#  ('спартак', 3),
#  ('рук', 3),
#  ('федерации', 3),
#  ('однотонная', 3),
#  ('фигурная,', 3),
#  ('коротки', 3),
#  ('bb', 3),
#  ('pro', 3),
#  ('100', 3),
#  ('широкий', 3),
#  ('мини', 3),
#  ('тренажер', 3),
#  ('подтяжка', 3),
#  ('strike', 3),
#  ('штука', 3),
#  ('5,', 3),
#  ('600мл', 3),
#  ('латекс', 3),
#  ('ширина', 3),
#  ('шнурком', 3),
#  ('улице', 3),
#  ('клетку', 3),
#  ('полосами', 3),
#  ('"футбольный', 3),
#  ('мяч"', 3),
#  ('хлопоквые', 3),
#  ('24х16', 3),
#  ('ремешок', 3),
#  ('шлема', 3),
#  ('u', 3),
#  ('nk', 3),
#  ('elite', 3),
#  ('crew', 3),
#  ('"триколор"', 3),
#  ('2,7', 3),
#  ('метра', 3),
#  ('отверстием', 3),
#  ('«вилка»', 3),
#  ('средние', 3),
#  ('зеленый-желтый-красный', 3),
#  ('официальная', 3),
#  ('163', 3),
#  ('170', 3),
#  ('игровой', 3),
#  ('клюшка+1', 3),
#  ('«лента»', 3),
#  ('туриста,', 3),
#  ('для…', 3),
#  ('fox', 3),
#  ('classic', 3),
#  ('напульсник,', 2),
#  ('хоккея', 2),
#  ('шайбой', 2),
#  ('гелевым', 2),
#  ('ленты', 2),
#  ('велосипеда', 2),
#  ('суппорт,', 2),
#  ('резинкой', 2),
#  ('z', 2),
#  ('победа', 2),
#  ('душнила', 2),
#  ('спайк', 2),
#  ('котятами', 2),
#  ('переноски', 2),
#  ('латексные', 2),
#  ('5смx5м', 2),
#  ('победы"', 2),
#  ('эластичные', 2),
#  ('подарочная', 2),
#  ('футбольная', 2),
#  ('подростковая', 2),
#  ('мужчин', 2),
#  ('stripe', 2),
#  ('(40-44)', 2),
#  ('модики', 2),
#  ('желтыми', 2),
#  ('манчестер', 2),
#  ('тельняшка', 2),
#  ('овала', 2),
#  ('голень', 2),
#  ('палке', 2),
#  ('пар,', 2),
#  ('спортом', 2),
#  ('фитнесом', 2),
#  ('треккинга', 2),
#  ('хайкинга', 2),
#  ('начёсом', 2),
#  ('девочек,', 2),
#  ('"ссср.', 2),
#  ('молот",', 2),
#  ('shark', 2),
#  ('нарукавники', 2),
#  ('насоса,', 2),
#  ('16x24', 2),
#  ('утеплённые', 2),
#  ('полоски', 2),
#  ('походный', 2),
#  ('su-403', 2),
#  ('т', 2),
#  ('громкий.', 2),
#  ('nike', 2),
#  ('голеностопный,', 2),
#  ('gorilla', 2),
#  ('2017', 2),
#  ('дева', 2),
#  ('козерог', 2),
#  ('туризм', 2),
#  ('овен', 2),
#  ('телец', 2),
#  ('начесом,', 2),
#  ('спортивная,', 2),
#  ('600', 2),
#  ('"автомобильные', 2),
#  ('"рожденный', 2),
#  ('"военная', 2),
#  ('вмф', 2),
#  ('"россия",', 2),
#  ('"морские', 2),
#  ('части', 2),
#  ('погранвойск",', 2),
#  ('"разведка', 2),
#  ('вдв",', 2),
#  ('пво', 2),
#  ('"вмф', 2),
#  ('20x30', 2),
#  ('пехота",', 2),
#  ('викинг', 2),
#  ('90*145', 2),
#  ('флага', 2),
#  ('30х20', 2),
#  ('julquin', 2),
#  ('крутой', 2),
#  ('пилоне', 2),
#  ('напульсники…', 2),
#  ('разм.35-39', 2),
#  ('кольцо', 2),
#  ('аэрохоккея', 2),
#  ('sock', 2),
#  ('длинных', 2),
#  ('семья', 2),
#  ('красный-белый-желтый', 2),
#  ('90х140', 2),
#  ('⭐️⭐️⭐️⭐️⭐️кинезио', 2),
#  ('влагостойкий', 2),
#  ('фиксирующие', 2),
#  ('(гольфа)', 2),
#  ('черный', 2),
#  ('игр', 2),
#  ('фиолетовые', 2),
#  ('куриные', 2),
#  ('лапки', 2),
#  ('бордовые', 2),
#  ('женских', 2),
#  ('секций', 2),
#  ('прикол', 2),
#  ('шлемов', 2),
#  ('3d', 2),
#  ('поддержкой', 2),
#  ('2,8', 2),
#  ('хаки', 2),
#  ('6х6х2', 2),
#  ('92', 2),
#  ('демисезонные', 2),
#  ('🍀🔝наколенники', 2),
#  ('22', 2),
#  ('косметические', 2),
#  ('флагштоке', 2),
#  ('40х30', 2),
#  ('полоска', 2),
#  ('розовые', 2),
#  ('при', 2),
#  ('артрозе', 2),
#  ('хоккей,', 2),
#  ('серый', 2),
#  ('3,8х5', 2),
#  ('колена,', 2),
#  ('денди', 2),
#  ('классическая', 2),
#  ('монголия', 2),
#  ('пилотка', 2),
#  ('военная', 2),
#  ('солдатская', 2),
#  ('офис', 2),
#  ('собак', 2),
#  ('базовые', 2),
#  ('хоккейных,', 2),
#  ('fit', 2),
#  ('живота,', 2),
#  ('разм.20-22', 2),
#  ('(7-9', 2),
#  ('лет)', 2),
#  ('вискозы', 2),
#  ('бирюзовый', 2),
#  ('тёплые', 2),
#  ('бежевый', 2),
#  ('голеностоп,ортез', 2),
#  ('50', 2),
#  ('ноские', 2),
#  ('носо…', 2),
#  ('21х22', 2),
#  ('перцы', 2),
#  ('чили', 2),
#  ('борцовка', 2),
#  ('мужская', 2),
#  ('школу,', 2),
#  ('насадок', 2),
#  ('красный', 2),
#  ('рейтузы', 2),
#  ('мл)', 2),
#  ('детские,', 2),
#  ('нательное', 2),
#  ('шнур', 2),
#  ('тролли', 2),
#  ('тачки', 2),
#  ('60х90см', 2),
#  ('мини-баскетбол.', 2),
#  ('настольная', 2),
#  ('суппорт(фиксатор)', 2),
#  ('фиксирующий', 2),
#  ('h-16см', 2),
#  ('морщин,', 2),
#  ('яркие,', 2),
#  ('tulle', 2),
#  ('классика,', 2),
#  ('защитном', 2),
#  ('футляре', 2),
#  ('силиконовой', 2),
#  ('пяткой', 2),
#  ('40-44', 2),
#  ('зима', 2),
#  ('20', 2),
#  ('зеленый', 2),
#  ('подростка', 2),
#  ('масок', 2),
#  ('пвх,', 2),
#  ('230', 2),
#  ('грамм', 2),
#  ('мячом', 2),
#  ('маус', 2),
#  ('тренировочных', 2),
#  ('футзального', 2),
#  ('низким', 2),
#  ('отскоком,', 2),
#  ('пвх', 2),
#  ('накачивание', 2),
#  ('наколенник-бандаж', 2),
#  ('в…', 2),
#  ('резиновый', 2),
#  ('5мм', 2),
#  ('3.0', 2),
#  ('супергерои', 2),
#  ('марвел,', 2),
#  ('супермен', 2),
#  ('карты', 2),
#  ('деньги', 2),
#  ('накачку', 2),
#  ('пауки', 2),
#  ('малыша', 2),
#  ('насадки', 2),
#  ('12шт', 2),
#  ('защитник', 2),
#  ('палочке,', 2),
#  ('перьями', 2),
#  ('бассейна', 2),
#  ('пляжный', 2),
#  ('(взрослые)', 2),
#  ('30см', 2),
#  ('сувенирная', 2),
#  ('нхл', 2),
#  ('чм', 2),
#  ('ои', 2),
#  ('силовой', 2),
#  ('петля', 2),
#  ('велосипедная', 2),
#  ('0,4', 2),
#  ('набор,', 2),
#  ('pc', 2),
#  ('баскетбол', 2),
#  ('синий-желтый-красный', 2),
#  ('(2', 2),
#  ('синий-белый-красный', 2),
#  ('карточек', 2),
#  ('сумка', 2),
#  ('одного', 2),
#  ('пластиковый,', 2),
#  ('желтый-белый-синий', 2),
#  ('школа', 2),
#  ('силиконовыми', 2),
#  ('вставками', 2),
#  ('стеклянная', 2),
#  ('"моя', 2),
#  ('"просто', 2),
#  ('30х20,', 2),
#  ('10шт', 2),
#  ('логотипом', 2),
#  ('фк', 2),
#  ('(иглы', 2),
#  ('насоса)', 2),
#  ('400мл', 2),
#  ('2-х', 2),
#  ('80', 2),
#  ('высоких', 2),
#  ...]

# %%
most_common_lemmas[0:30]
# Out:
# [('носки', 2098),
#  ('для', 1735),
#  ('с', 1113),
#  ('высокие', 1056),
#  ('спортивные', 878),
#  ('гетры', 804),
#  ('мужские', 720),
#  ('принтом', 703),
#  ('женские', 683),
#  ('набор', 601),
#  ('длинные', 597),
#  ('гольфы', 509),
#  ('футбольные', 453),
#  ('и', 403),
#  ('на', 333),
#  ('пары', 312),
#  ('1', 307),
#  ('белые', 306),
#  ('спортивный', 293),
#  ('хлопок', 290),
#  ('кинезио', 277),
#  ('короткие', 269),
#  ('тела', 268),
#  ('лица', 262),
#  ('тейп', 257),
#  ('в', 255),
#  ('флаг', 247),
#  ('пара', 242),
#  ('детские', 240),
#  ('2', 230)]

# %%
# Самые широко представленные товары в этой ценовой категории - носки, гетры, гольфы, тейпы, флаги
